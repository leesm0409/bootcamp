# %% [markdown]
# <a href="https://colab.research.google.com/github/leesm0409/bootcamp/blob/main/10__(1)CNN_%EB%AA%A8%EB%8D%B8%EC%9D%84_%EC%82%AC%EC%9A%A9%ED%95%9C_%EA%B0%9C%EC%99%80_%EA%B3%A0%EC%96%91%EC%9D%B4_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EB%B6%84%EB%A5%98%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 모델을 사용한 개와 고양이 이미지 분류하기

# %% [markdown]
# ## 데이터 준비하기

# %% [markdown]
# ### colab을 이용 - google api를 통해 데이터 불러오기

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2023-08-14 05:52:38--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.134.128, 74.125.139.128, 74.125.141.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.134.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   121MB/s    in 0.5s
#
# 2023-08-14 05:52:38 (121 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %% [markdown]
# ### 데이터 폴더 나누기

# %%
# 압축풀기
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# 데이터 경로 설정
rootPath = '/tmp/cats_and_dogs_filtered'

# 훈련셋, 검증셋 경로
train_dir = os.path.join(rootPath, 'train') # /tmp/cats_and_dogs_filtered/train
validation_dir = os.path.join(rootPath, 'validation')  # /tmp/cats_and_dogs_filtered/validation

# 훈련셋 중에 고양이 사진 경로
train_cats_dir = os.path.join(train_dir, 'cats') # /tmp/cats_and_dogs_filtered/train/cats
# 훈련셋 중에 강아지 사진 경로
train_dogs_dir = os.path.join(train_dir, 'dogs') # /tmp/cats_and_dogs_filtered/train/dogs


# 검증셋 중에 고양이 사진 경로
validation_cats_dir = os.path.join(validation_dir, 'cats') # /tmp/cats_and_dogs_filtered/validation/cats
# 검증셋 중에 강아지 사진 경로
validation_dogs_dir = os.path.join(validation_dir, 'dogs') # /tmp/cats_and_dogs_filtered/validation/dogs

# %% [markdown]
# ## 데이터 확인하기

# %%
train_cat_fnames = os.listdir(train_cats_dir)
train_cat_fnames.sort()
#print(train_cat_fnames[:10])

print('훈련 데이터 중 고양이 사진 수 : ', len(os.listdir(train_cats_dir)))
print('훈련 데이터 중 강아지 사진 수 : ', len(os.listdir(train_dogs_dir)))

print('검증 데이터 중 고양이 사진 수 : ', len(os.listdir(validation_cats_dir)))
print('검증 데이터 중 강아지 사진 수 : ', len(os.listdir(validation_dogs_dir)))
# Out:
# 훈련 데이터 중 고양이 사진 수 :  1000
# 훈련 데이터 중 강아지 사진 수 :  1000
# 검증 데이터 중 고양이 사진 수 :  500
# 검증 데이터 중 강아지 사진 수 :  500

# %% [markdown]
# ## 데이터 증식 (Data Argumentation)

# %%
import os
from keras.preprocessing.image import ImageDataGenerator

# 데이터 경로 설정
rootPath = '/tmp/cats_and_dogs_filtered'

# 스케일링 + 데이터 증식 속성 설정
trainImageGenerator = ImageDataGenerator(rescale=1./255,
                                         horizontal_flip = True,
                                         vertical_flip = True,
                                         shear_range = 0.5,
                                         brightness_range = [0.5, 1.5],
                                         zoom_range = 0.2,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         rotation_range = 30,
                                         fill_mode = 'nearest')

# 스케일링 설정
testImageGenerator =  ImageDataGenerator(rescale=1./255)


# 데이터 스케일링 및 증식
trainGen = trainImageGenerator.flow_from_directory(
    os.path.join(rootPath, 'train'),
    target_size=(64, 64),
    class_mode = 'binary'
)

testGen = testImageGenerator.flow_from_directory(
    os.path.join(rootPath, 'validation'),
    target_size=(64, 64),
    class_mode = 'binary'
)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
print(trainGen.class_indices)
print(testGen.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}
# {'cats': 0, 'dogs': 1}

# %% [markdown]
# ## 이미지 그려보기

# %%
from tensorflow.keras.preprocessing.image import array_to_img
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5, 5))

for i in range(9):
  data = next(trainGen)
  arr = data[0][0]
  plt.subplot(3, 3, i+1)
  plt.xticks([]) # 눈금 지우기
  plt.yticks([])
  img = array_to_img(arr).resize((128, 128))
  plt.imshow(img)

plt.show()

# %%
label_index = trainGen.class_indices

# {'cats': 0, 'dogs': 1}
x, y = trainGen.next()

for i in range(0, 3):
  image = x[i]
  label = y[i].astype('int')
  plt.xticks([]) # 눈금 지우기
  plt.yticks([])
  print('사진 : {}'.format([k for k, v in label_index.items() if v == label]))
  print('사진 : {}'.format(label))
  plt.imshow(image)
  plt.show()
# Out:
# 사진 : ['cats']
# 사진 : 0
# 사진 : ['cats']
# 사진 : 0
# 사진 : ['dogs']
# 사진 : 1

# %% [markdown]
# ## 간단한 CNN 모델 구성

# %%
from keras.models import Sequential
from keras import layers

model = Sequential()

model.add(layers.InputLayer(input_shape=(64, 64, 3)))
model.add(layers.Conv2D(filters = 16, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Dropout(rate=0.3))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 64, 64, 16)        448
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 16)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 16)        0
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 32)        0
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 256)               2097408
#
#  dense_7 (Dense)             (None, 64)                16448
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,119,009
# Trainable params: 2,119,009
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 모델 설정하기

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['acc'])

# %% [markdown]
# ### 모델 학습하기

# %%
history = model.fit(trainGen, epochs=64, validation_data=testGen)
# Out:
# Epoch 1/64
# 63/63 [==============================] - 19s 123ms/step - loss: 0.7245 - acc: 0.5145 - val_loss: 0.6930 - val_acc: 0.4980
# Epoch 2/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.6930 - acc: 0.5155 - val_loss: 0.6928 - val_acc: 0.5020
# Epoch 3/64
# 63/63 [==============================] - 7s 104ms/step - loss: 0.6868 - acc: 0.5545 - val_loss: 0.6853 - val_acc: 0.5540
# Epoch 4/64
# 63/63 [==============================] - 9s 149ms/step - loss: 0.6744 - acc: 0.5790 - val_loss: 0.6660 - val_acc: 0.6050
# Epoch 5/64
# 63/63 [==============================] - 8s 126ms/step - loss: 0.6571 - acc: 0.6030 - val_loss: 0.6435 - val_acc: 0.6300
# Epoch 6/64
# 63/63 [==============================] - 8s 126ms/step - loss: 0.6509 - acc: 0.6135 - val_loss: 0.6360 - val_acc: 0.6220
# Epoch 7/64
# 63/63 [==============================] - 9s 144ms/step - loss: 0.6374 - acc: 0.6430 - val_loss: 0.6182 - val_acc: 0.6430
# Epoch 8/64
# 63/63 [==============================] - 12s 187ms/step - loss: 0.6243 - acc: 0.6440 - val_loss: 0.6327 - val_acc: 0.6290
# Epoch 9/64
# 63/63 [==============================] - 7s 104ms/step - loss: 0.6530 - acc: 0.5950 - val_loss: 0.6546 - val_acc: 0.6180
# Epoch 10/64
# 63/63 [==============================] - 7s 119ms/step - loss: 0.6280 - acc: 0.6335 - val_loss: 0.6184 - val_acc: 0.6450
# Epoch 11/64
# 63/63 [==============================] - 7s 104ms/step - loss: 0.6153 - acc: 0.6595 - val_loss: 0.6276 - val_acc: 0.6730
# Epoch 12/64
# 63/63 [==============================] - 6s 103ms/step - loss: 0.6160 - acc: 0.6595 - val_loss: 0.6163 - val_acc: 0.6640
# Epoch 13/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.6025 - acc: 0.6620 - val_loss: 0.5991 - val_acc: 0.6790
# Epoch 14/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.6087 - acc: 0.6525 - val_loss: 0.6183 - val_acc: 0.6470
# Epoch 15/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.6120 - acc: 0.6655 - val_loss: 0.6021 - val_acc: 0.6690
# Epoch 16/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5958 - acc: 0.6755 - val_loss: 0.5912 - val_acc: 0.6920
# Epoch 17/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.6030 - acc: 0.6645 - val_loss: 0.5947 - val_acc: 0.6810
# Epoch 18/64
# 63/63 [==============================] - 7s 110ms/step - loss: 0.5995 - acc: 0.6730 - val_loss: 0.6191 - val_acc: 0.6470
# Epoch 19/64
# 63/63 [==============================] - 7s 113ms/step - loss: 0.5996 - acc: 0.6640 - val_loss: 0.5992 - val_acc: 0.6780
# Epoch 20/64
# 63/63 [==============================] - 8s 130ms/step - loss: 0.5939 - acc: 0.6655 - val_loss: 0.6236 - val_acc: 0.6420
# Epoch 21/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.5845 - acc: 0.6750 - val_loss: 0.5932 - val_acc: 0.6900
# Epoch 22/64
# 63/63 [==============================] - 7s 104ms/step - loss: 0.5831 - acc: 0.6855 - val_loss: 0.5907 - val_acc: 0.6820
# Epoch 23/64
# 63/63 [==============================] - 7s 115ms/step - loss: 0.6057 - acc: 0.6590 - val_loss: 0.6003 - val_acc: 0.6880
# Epoch 24/64
# 63/63 [==============================] - 8s 119ms/step - loss: 0.5921 - acc: 0.6830 - val_loss: 0.5937 - val_acc: 0.6800
# Epoch 25/64
# 63/63 [==============================] - 7s 106ms/step - loss: 0.5859 - acc: 0.6810 - val_loss: 0.5918 - val_acc: 0.6910
# Epoch 26/64
# 63/63 [==============================] - 8s 121ms/step - loss: 0.5793 - acc: 0.6975 - val_loss: 0.5893 - val_acc: 0.6680
# Epoch 27/64
# 63/63 [==============================] - 8s 121ms/step - loss: 0.5941 - acc: 0.6710 - val_loss: 0.5842 - val_acc: 0.6920
# Epoch 28/64
# 63/63 [==============================] - 8s 128ms/step - loss: 0.5761 - acc: 0.6755 - val_loss: 0.5954 - val_acc: 0.6500
# Epoch 29/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.5759 - acc: 0.6895 - val_loss: 0.5837 - val_acc: 0.6920
# Epoch 30/64
# 63/63 [==============================] - 7s 118ms/step - loss: 0.5757 - acc: 0.6950 - val_loss: 0.5787 - val_acc: 0.6860
# Epoch 31/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.5815 - acc: 0.6820 - val_loss: 0.5929 - val_acc: 0.6770
# Epoch 32/64
# 63/63 [==============================] - 7s 119ms/step - loss: 0.5877 - acc: 0.6740 - val_loss: 0.6212 - val_acc: 0.6540
# Epoch 33/64
# 63/63 [==============================] - 6s 102ms/step - loss: 0.5859 - acc: 0.6785 - val_loss: 0.5898 - val_acc: 0.6710
# Epoch 34/64
# 63/63 [==============================] - 8s 119ms/step - loss: 0.5748 - acc: 0.6890 - val_loss: 0.5766 - val_acc: 0.7050
# Epoch 35/64
# 63/63 [==============================] - 7s 114ms/step - loss: 0.5677 - acc: 0.6910 - val_loss: 0.6112 - val_acc: 0.6610
# Epoch 36/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.5637 - acc: 0.7005 - val_loss: 0.5999 - val_acc: 0.6690
# Epoch 37/64
# 63/63 [==============================] - 7s 118ms/step - loss: 0.5613 - acc: 0.6975 - val_loss: 0.5683 - val_acc: 0.7140
# Epoch 38/64
# 63/63 [==============================] - 7s 107ms/step - loss: 0.5654 - acc: 0.7050 - val_loss: 0.5772 - val_acc: 0.7040
# Epoch 39/64
# 63/63 [==============================] - 8s 123ms/step - loss: 0.5592 - acc: 0.7125 - val_loss: 0.5806 - val_acc: 0.6990
# Epoch 40/64
# 63/63 [==============================] - 8s 130ms/step - loss: 0.5601 - acc: 0.7035 - val_loss: 0.5764 - val_acc: 0.6970
# Epoch 41/64
# 63/63 [==============================] - 7s 110ms/step - loss: 0.5541 - acc: 0.7105 - val_loss: 0.5821 - val_acc: 0.6970
# Epoch 42/64
# 63/63 [==============================] - 8s 126ms/step - loss: 0.5500 - acc: 0.7115 - val_loss: 0.5666 - val_acc: 0.7060
# Epoch 43/64
# 63/63 [==============================] - 7s 118ms/step - loss: 0.5505 - acc: 0.7045 - val_loss: 0.5716 - val_acc: 0.7040
# Epoch 44/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.5514 - acc: 0.7025 - val_loss: 0.5770 - val_acc: 0.7210
# Epoch 45/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5528 - acc: 0.7045 - val_loss: 0.5928 - val_acc: 0.6590
# Epoch 46/64
# 63/63 [==============================] - 8s 127ms/step - loss: 0.5435 - acc: 0.7030 - val_loss: 0.5873 - val_acc: 0.6830
# Epoch 47/64
# 63/63 [==============================] - 7s 106ms/step - loss: 0.5389 - acc: 0.7190 - val_loss: 0.5892 - val_acc: 0.6890
# Epoch 48/64
# 63/63 [==============================] - 7s 114ms/step - loss: 0.5433 - acc: 0.7175 - val_loss: 0.5971 - val_acc: 0.6940
# Epoch 49/64
# 63/63 [==============================] - 7s 119ms/step - loss: 0.5322 - acc: 0.7125 - val_loss: 0.5596 - val_acc: 0.7260
# Epoch 50/64
# 63/63 [==============================] - 7s 106ms/step - loss: 0.5324 - acc: 0.7250 - val_loss: 0.5681 - val_acc: 0.7100
# Epoch 51/64
# 63/63 [==============================] - 8s 122ms/step - loss: 0.5495 - acc: 0.7310 - val_loss: 0.5583 - val_acc: 0.7110
# Epoch 52/64
# 63/63 [==============================] - 7s 118ms/step - loss: 0.5289 - acc: 0.7320 - val_loss: 0.5693 - val_acc: 0.7240
# Epoch 53/64
# 63/63 [==============================] - 7s 108ms/step - loss: 0.5342 - acc: 0.7275 - val_loss: 0.5685 - val_acc: 0.7190
# Epoch 54/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5339 - acc: 0.7130 - val_loss: 0.5658 - val_acc: 0.7140
# Epoch 55/64
# 63/63 [==============================] - 7s 107ms/step - loss: 0.5324 - acc: 0.7310 - val_loss: 0.5527 - val_acc: 0.7210
# Epoch 56/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5219 - acc: 0.7315 - val_loss: 0.5723 - val_acc: 0.7160
# Epoch 57/64
# 63/63 [==============================] - 7s 109ms/step - loss: 0.5278 - acc: 0.7295 - val_loss: 0.5579 - val_acc: 0.7270
# Epoch 58/64
# 63/63 [==============================] - 7s 107ms/step - loss: 0.5169 - acc: 0.7395 - val_loss: 0.5819 - val_acc: 0.6800
# Epoch 59/64
# 63/63 [==============================] - 7s 106ms/step - loss: 0.5320 - acc: 0.7275 - val_loss: 0.5705 - val_acc: 0.7110
# Epoch 60/64
# 63/63 [==============================] - 7s 105ms/step - loss: 0.5201 - acc: 0.7285 - val_loss: 0.5506 - val_acc: 0.7240
# Epoch 61/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5110 - acc: 0.7340 - val_loss: 0.5554 - val_acc: 0.7160
# Epoch 62/64
# 63/63 [==============================] - 8s 126ms/step - loss: 0.5179 - acc: 0.7310 - val_loss: 0.5676 - val_acc: 0.7220
# Epoch 63/64
# 63/63 [==============================] - 7s 104ms/step - loss: 0.5148 - acc: 0.7455 - val_loss: 0.5672 - val_acc: 0.7240
# Epoch 64/64
# 63/63 [==============================] - 8s 120ms/step - loss: 0.5256 - acc: 0.7310 - val_loss: 0.5777 - val_acc: 0.6990

# %% [markdown]
# ## 학습 결과 분석

# %%
import matplotlib.pyplot as plt

his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %%
model.evaluate(testGen)
# Out:
# 32/32 [==============================] - 2s 56ms/step - loss: 0.5777 - acc: 0.6990
# [0.5777403712272644, 0.6990000009536743]

# %% [markdown]
# ## 모델 예측하기

# %%
from tensorflow.keras.preprocessing.image import array_to_img
import numpy as np

label_index = ['고양이', '강아지']

x, y = testGen.next()
for i in range(0,3):
  image = x[i]
  label = y[i].astype('int')

  y_prob = model.predict(image.reshape(1, 64, 64, 3))
  y_prob_class = (model.predict(image.reshape(1, 64, 64, 3)) > 0.5 ).astype('int')[0][0]
  print('정답: {}'.format(label_index[label]), ' label :', label)
  print('예측: {}'.format(label_index[y_prob_class]), ' predicted value :', y_prob)
  plt.imshow(image)
  plt.show()
# Out:
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 17ms/step
# 정답: 고양이  label : 0
# 예측: 고양이  predicted value : [[0.24951902]]
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 정답: 고양이  label : 0
# 예측: 고양이  predicted value : [[0.36005786]]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 정답: 강아지  label : 1
# 예측: 강아지  predicted value : [[0.530112]]

# %% [markdown]
# ## 사전학습 모델을 활용해서 예측 정확도 올리기
#
# *   학습데이터, 테스트 데이터 그대로 사용
# *   첫번째 모델 VGG16 사용 + GlobalAveragePooling2D() + Flatten() + Dense(256) + Dense(64) + Dense(1)
# *   두번째 모델 ResNet50V 사용 + GlobalAveragePooling2D() + Flatten() + Dense(256) + Dense(64) + Dense(1)
# *   두개의 모델의 성능을 비교

# %% [markdown]
# ## 정확도가 높은 분류 모델 구성 - 전이학습 모델
#
# *   과대 적합 피하고, 정확도는 높이기
# *   VGG16(Visual Geometry Group) 모델을 활용한 분류 모델 구성

# %%
from keras.models import Sequential
from keras.applications import VGG16
from keras.layers import Conv2D, GlobalAveragePooling2D, Dropout, Flatten, Dense
from keras.optimizers import Adam

# 전이 학습 모델 가져오기
pre_trained_vgg = VGG16(input_shape=(32,32,3), include_top=False, weights='imagenet')
pre_trained_vgg.summary()

# 분류모델 합치기
model = Sequential()
model.add(pre_trained_vgg)
model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.1))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = Adam(1e-4),
             loss = 'sparse_categorical_crossentropy', #원-핫 인코딩 사용하지 않는 경우 (0-9 레이블 그대로 사용하는 경우)
             metrics = ['acc'])

history = model.fit(testGen,
                    epochs = 15,
                    batch_size = 32,
                    validation_data = (testGen))
# Out:
# Epoch 1/15
# 32/32 [==============================] - 4s 106ms/step - loss: nan - acc: 0.5010 - val_loss: nan - val_acc: 0.5000
# Epoch 2/15
# 32/32 [==============================] - 4s 137ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 3/15
# 32/32 [==============================] - 3s 97ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 4/15
# 32/32 [==============================] - 3s 96ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 5/15
# 32/32 [==============================] - 3s 97ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 6/15
# 32/32 [==============================] - 4s 120ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 7/15
# 32/32 [==============================] - 3s 98ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 8/15
# 32/32 [==============================] - 3s 99ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 9/15
# 32/32 [==============================] - 4s 122ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 10/15
# 32/32 [==============================] - 3s 97ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 11/15
# 32/32 [==============================] - 4s 137ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 12/15
# 32/32 [==============================] - 3s 101ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 13/15
# 32/32 [==============================] - 3s 99ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 14/15
# 32/32 [==============================] - 3s 99ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 15/15
# 32/32 [==============================] - 4s 124ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000

# %% [markdown]
# ## 학습 결과 분석

# %%
his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %%
model.evaluate(testGen)
# Out:
# 32/32 [==============================] - 2s 48ms/step - loss: nan - acc: 0.5000
# [nan, 0.5]

# %% [markdown]
# ## 모델 ResNet50V 사용 + GlobalAveragePooling2D() + Flatten() + Dense(256) + Dense(64) + Dense(1)

# %%
from keras.models import Sequential
from keras.applications import ResNet50V2
from keras.layers import Conv2D, GlobalAveragePooling2D, Dropout, Flatten, Dense
from keras.optimizers import Adam

# 전이 학습 모델 가져오기
pre_trained_50v2 = ResNet50V2(input_shape=(32,32,3), include_top=False, weights='imagenet')
pre_trained_50v2.summary()

# 분류모델 합치기
model = Sequential()
model.add(pre_trained_50v2)
model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.1))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_16[0][0]']
#
#  conv1_conv (Conv2D)            (None, 16, 16, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 18, 18, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 8, 8, 64)     0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 8, 8, 64)    256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 8, 8, 64)    0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 8, 8, 64)     4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 10, 10, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 8, 8, 64)     36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 8, 8, 256)    0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 8, 8, 256)   1024        ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 8, 8, 256)   0           ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 8, 8, 64)     16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 10, 10, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 8, 8, 64)     36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 8, 8, 256)    0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 8, 8, 256)   1024        ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 8, 8, 256)   0           ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 8, 8, 64)     16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 10, 10, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 4, 4, 64)     36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 4, 4, 64)    256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 4, 4, 64)    0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 4, 4, 256)   0           ['conv2_block2_out[0][0]']
#  )
#
#  conv2_block3_3_conv (Conv2D)   (None, 4, 4, 256)    16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 4, 4, 256)    0           ['max_pooling2d_14[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 4, 4, 256)   1024        ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 4, 4, 256)   0           ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 4, 4, 128)    32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 4, 4, 512)    131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 4, 4, 512)    0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 4, 4, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 4, 4, 512)    0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 2, 2, 128)    147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 2, 2, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 2, 2, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 2, 2, 512)   0           ['conv3_block3_out[0][0]']
#  )
#
#  conv3_block4_3_conv (Conv2D)   (None, 2, 2, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 2, 2, 512)    0           ['max_pooling2d_15[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 2, 2, 512)   2048        ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 2, 2, 512)   0           ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 2, 2, 256)    131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 2, 2, 1024)   525312      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_0_conv[0][0]',
#                                                                   'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block1_out[0][0]']
#  ormalization)
#
#  conv4_block2_preact_relu (Acti  (None, 2, 2, 1024)  0           ['conv4_block2_preact_bn[0][0]']
#  vation)
#
#  conv4_block2_1_conv (Conv2D)   (None, 2, 2, 256)    262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block2_out[0][0]']
#  ormalization)
#
#  conv4_block3_preact_relu (Acti  (None, 2, 2, 1024)  0           ['conv4_block3_preact_bn[0][0]']
#  vation)
#
#  conv4_block3_1_conv (Conv2D)   (None, 2, 2, 256)    262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block3_out[0][0]']
#  ormalization)
#
#  conv4_block4_preact_relu (Acti  (None, 2, 2, 1024)  0           ['conv4_block4_preact_bn[0][0]']
#  vation)
#
#  conv4_block4_1_conv (Conv2D)   (None, 2, 2, 256)    262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block4_out[0][0]']
#  ormalization)
#
#  conv4_block5_preact_relu (Acti  (None, 2, 2, 1024)  0           ['conv4_block5_preact_bn[0][0]']
#  vation)
#
#  conv4_block5_1_conv (Conv2D)   (None, 2, 2, 256)    262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block5_out[0][0]']
#  ormalization)
#
#  conv4_block6_preact_relu (Acti  (None, 2, 2, 1024)  0           ['conv4_block6_preact_bn[0][0]']
#  vation)
#
#  conv4_block6_1_conv (Conv2D)   (None, 2, 2, 256)    262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 1, 1, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 1, 1, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 1, 1, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_16 (MaxPooling2D  (None, 1, 1, 1024)  0           ['conv4_block5_out[0][0]']
#  )
#
#  conv4_block6_3_conv (Conv2D)   (None, 1, 1, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 1, 1, 1024)   0           ['max_pooling2d_16[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 1, 1, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 1, 1, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 1, 1, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 3, 3, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 1, 1, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 1, 1, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 1, 1, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 1, 1, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 1, 1, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 3, 3, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 1, 1, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 1, 1, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 1, 1, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 1, 1, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 3, 3, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 1, 1, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 1, 1, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 1, 1, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 1, 1, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = Adam(1e-4),
             loss = 'sparse_categorical_crossentropy', #원-핫 인코딩 사용하지 않는 경우 (0-9 레이블 그대로 사용하는 경우)
             metrics = ['acc'])

history = model.fit(testGen,
                    epochs = 15,
                    batch_size = 32,
                    validation_data = (testGen))
# Out:
# Epoch 1/15
# 32/32 [==============================] - 10s 133ms/step - loss: nan - acc: 0.4990 - val_loss: nan - val_acc: 0.5000
# Epoch 2/15
# 32/32 [==============================] - 4s 139ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 3/15
# 32/32 [==============================] - 3s 102ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 4/15
# 32/32 [==============================] - 3s 100ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 5/15
# 32/32 [==============================] - 4s 129ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 6/15
# 32/32 [==============================] - 3s 103ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 7/15
# 32/32 [==============================] - 4s 140ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 8/15
# 32/32 [==============================] - 4s 126ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 9/15
# 32/32 [==============================] - 3s 102ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 10/15
# 32/32 [==============================] - 4s 113ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 11/15
# 32/32 [==============================] - 4s 138ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 12/15
# 32/32 [==============================] - 3s 101ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 13/15
# 32/32 [==============================] - 3s 101ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 14/15
# 32/32 [==============================] - 3s 109ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000
# Epoch 15/15
# 32/32 [==============================] - 3s 101ms/step - loss: nan - acc: 0.5000 - val_loss: nan - val_acc: 0.5000

# %%
his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %%
model.evaluate(testGen)
# Out:
# 32/32 [==============================] - 2s 49ms/step - loss: 3.3596e-04 - acc: 1.0000
# [0.00033596332650631666, 1.0]
