# %% [markdown]
# <a href="https://colab.research.google.com/github/leesm0409/bootcamp/blob/main/14_DBSCAN_%EA%B3%A0%EB%93%B1%ED%95%99%EA%B5%90_%EC%A7%84%ED%95%99%EB%A5%A0_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_%EC%A4%91%ED%95%99%EA%B5%90_%EA%B5%B0%EC%A7%91%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DBSCAN 고등학교 진학률 데이터를 활용한 중학교 군집분석 및 지도 시각화

# %%
# !pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)

# %%
import pandas as pd
import koreanize_matplotlib

# %% [markdown]
# ##데이터 준비하기

# %%
df = pd.read_excel('/content/2016_middle_shcool_graduates_report.xlsx', index_col=0, engine='openpyxl')
df
# Out:
#       지역               학교명  코드  유형  주야  남학생수  여학생수    일반고   특성화고    과학고  \
# 0    성북구    서울대학교사범대학부설중학교   3  국립  주간   277     0  0.585  0.148  0.018
# 1    종로구  서울대학교사범대학부설여자중학교   3  국립  주간     0   256  0.680  0.199  0.000
# 2    강남구             개원중학교   3  공립  주간   170   152  0.817  0.047  0.009
# 3    강남구             개포중학교   3  공립  주간    83    72  0.755  0.097  0.013
# 4    서초구             경원중학교   3  공립  주간   199   212  0.669  0.017  0.007
# ..   ...               ...  ..  ..  ..   ...   ...    ...    ...    ...
# 410  강남구           국립국악중학교   9  국립  주간     9    91  0.060  0.000  0.000
# 411  금천구         국립전통예술중학교   9  국립  주간    14    42  0.107  0.000  0.000
# 412  광진구            선화예술학교   9  사립  주간    33   241  0.102  0.000  0.000
# 413   중구              예원학교   9  사립  주간    31   258  0.170  0.000  0.000
# 414  노원구           한국삼육중학교   9  사립  주간   105   102  0.908  0.019  0.000
#
#      외고_국제고  예고_체고  마이스터고    자사고    자공고   기타진학  취업     미상         위도  \
# 0     0.007  0.000  0.011  0.227  0.000  0.004   0  0.000  37.594942
# 1     0.035  0.008  0.000  0.043  0.004  0.031   0  0.000  37.577473
# 2     0.012  0.003  0.006  0.090  0.003  0.009   0  0.003  37.491637
# 3     0.013  0.019  0.019  0.065  0.000  0.019   0  0.000  37.480439
# 4     0.010  0.005  0.000  0.282  0.000  0.010   0  0.000  37.510750
# ..      ...    ...    ...    ...    ...    ...  ..    ...        ...
# 410   0.000  0.940  0.000  0.000  0.000  0.000   0  0.000  37.476381
# 411   0.000  0.875  0.000  0.000  0.000  0.000   0  0.018  37.446354
# 412   0.000  0.861  0.000  0.000  0.000  0.000   0  0.036  37.549642
# 413   0.000  0.751  0.000  0.000  0.000  0.048   0  0.031  37.566951
# 414   0.024  0.000  0.010  0.010  0.000  0.029   0  0.000  37.641056
#
#              경도
# 0    127.038909
# 1    127.003857
# 2    127.071744
# 3    127.062201
# 4    127.008900
# ..          ...
# 410  127.051355
# 411  126.906424
# 412  127.087737
# 413  126.971553
# 414  127.108344
#
# [415 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 415 entries, 0 to 414
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      415 non-null    object
#  1   학교명     415 non-null    object
#  2   코드      415 non-null    int64
#  3   유형      415 non-null    object
#  4   주야      415 non-null    object
#  5   남학생수    415 non-null    int64
#  6   여학생수    415 non-null    int64
#  7   일반고     415 non-null    float64
#  8   특성화고    415 non-null    float64
#  9   과학고     415 non-null    float64
#  10  외고_국제고  415 non-null    float64
#  11  예고_체고   415 non-null    float64
#  12  마이스터고   415 non-null    float64
#  13  자사고     415 non-null    float64
#  14  자공고     415 non-null    float64
#  15  기타진학    415 non-null    float64
#  16  취업      415 non-null    int64
#  17  미상      415 non-null    float64
#  18  위도      415 non-null    float64
#  19  경도      415 non-null    float64
# dtypes: float64(12), int64(4), object(4)
# memory usage: 68.1+ KB

# %%
import folium

mschool_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', zoom_start=12)


# 중학교의 위치정보를 CircleMarker로 표시 -> popup 학교명 출력
for name, lat, lng in zip(df.학교명, df.위도, df.경도):
  folium.CircleMarker([lat,lng], #위도, 경도
                      radius=5, # 반지름
                      color='brown', #둘레 색상
                      fill=True,
                      fill_color='coral', #원안에 색상
                      fill_opacity=0.7, #투명도
                      popup='<pre>'+name+'</pre>').add_to(mschool_map)


mschool_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9b5c3be03a4a6496baaee2a8134a83a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9b5c3be03a4a6496baaee2a8134a83a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9b5c3be03a4a6496baaee2a8134a83a = L.map(
#                 &quot;map_f9b5c3be03a4a6496baaee2a8134a83a&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52acc7f377ed362b9ce246abad823997 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9b5c3be03a4a6496baaee2a8134a83a);
#
#
#             var circle_marker_f526e2faf3bf4253dff0d76056ff46b6 = L.circleMarker(
#                 [37.5949423, 127.0389086],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f9b5c3be03a4a6496baaee2a8134a83a);
#
#
#         var popup_bf4a6146f34846de7054d44a90b2df35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cb6c432ab8917aee17f3ecd8e8b0fc5 = $(`&lt;div id=&quot;html_9cb6c432ab8917aee17f3ecd8e8b0fc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;서울대학교사범대학부설중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_bf4a6146f34846de7054d44a90b2df35.setContent(html_9cb6c432ab8917aee17f3ecd8e8b0fc5);
#
#
#
#         circle_marker_f526e2faf3bf4253dff0d76056ff46b6.bindPopup(popup_bf4a6146f34846de7054d44a90b2df35)
#         ;
#
#
#
#
#             var circle_marker_c8776a20b4b9d7b814c120289f958772 = L.circleMarker(
#                 [37.5774729, 127.0038567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f9b5c3be03a4a6496baaee2a8134a83a);
#
#
#         var popup_ba28a31aada89d497aac6efb2d145d6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a16a1aca6b81bd4e7d3dba74038231a = $(`&lt;div id=&quot;html_1a16a1aca6b81bd4e7d3dba74038231a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;서울대학교사범대학부설여자중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_ba28a31aada89d497aac6efb2d145d6a.setContent(html_1a16a1aca6b81bd4e7d3dba74038231a);
#
#
#
#         circle_marker_c8776a20b4b9d7b814c120289f958772.bindPopup(popup_ba28a31aada89d497aac6efb2d145d6a)
#         ;
#
#
#
#
#             var circle_marker_5ee30a3b3851cd1f622b2d3ce365d4e0 = L.circleMarker(
#                 [37.4916369, 127.0717443],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f9b5c3be03a4a6496baaee2a8134a83a);
#
#
#         var popup_1f7c9f7a3d2527acfd91d14683b65fb5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e13193ed2da8055591f6aa0510aab00 = $(`&lt;div id=&quot;html_3e13193ed2da8055591f6aa0510aab00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;개원중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_1f7c9f7a3d2527acfd91d14683b65fb5.setContent(html_3e13193ed2da8055591f6aa0510aab00);
#
#
#
#         circle_marker_5ee30a3b3851cd1f622b2d3ce365d4e0.bindPopup(popup_1f7c9f7a3

# %% [markdown]
# ## 데이터 전처리

# %%
df.head()
# Out:
#     지역               학교명  코드  유형  주야  남학생수  여학생수    일반고   특성화고    과학고  외고_국제고  \
# 0  성북구    서울대학교사범대학부설중학교   3  국립  주간   277     0  0.585  0.148  0.018   0.007
# 1  종로구  서울대학교사범대학부설여자중학교   3  국립  주간     0   256  0.680  0.199  0.000   0.035
# 2  강남구             개원중학교   3  공립  주간   170   152  0.817  0.047  0.009   0.012
# 3  강남구             개포중학교   3  공립  주간    83    72  0.755  0.097  0.013   0.013
# 4  서초구             경원중학교   3  공립  주간   199   212  0.669  0.017  0.007   0.010
#
#    예고_체고  마이스터고    자사고    자공고   기타진학  취업     미상         위도          경도
# 0  0.000  0.011  0.227  0.000  0.004   0  0.000  37.594942  127.038909
# 1  0.008  0.000  0.043  0.004  0.031   0  0.000  37.577473  127.003857
# 2  0.003  0.006  0.090  0.003  0.009   0  0.003  37.491637  127.071744
# 3  0.019  0.019  0.065  0.000  0.019   0  0.000  37.480439  127.062201
# 4  0.005  0.000  0.282  0.000  0.010   0  0.000  37.510750  127.008900

# %%
# 지역, 유형, 주야
df['지역'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df['유형'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df['주야'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### 범주형 데이터 인코딩
#
# *   지역 컬럼 -> 25개의 지역구
# *   유형 -> 3개의 유형 ( 국립, 공립, 사립)**굵은 텍스트**

# %%
# 범주형(텍스트) -> 라벨링(숫자형태로 변경) -> 성능에 따라서 인코딩으로 발전가능
from sklearn import preprocessing
import numpy as np

#1) 지역, 유형 컬럼 라벨링
label_encoder = preprocessing.LabelEncoder()
l_location = label_encoder.fit_transform(df['지역']) # 0 ~ 24
l_type = label_encoder.fit_transform(df['유형']) # 0 ~ 2

# %%
#2) 데이터프레임에 새로운 컬럼으로 추가
df['location'] = l_location
df['type'] = l_type

df.head()
# Out:
#     지역               학교명  코드  유형  주야  남학생수  여학생수    일반고   특성화고    과학고  ...  \
# 0  성북구    서울대학교사범대학부설중학교   3  국립  주간   277     0  0.585  0.148  0.018  ...
# 1  종로구  서울대학교사범대학부설여자중학교   3  국립  주간     0   256  0.680  0.199  0.000  ...
# 2  강남구             개원중학교   3  공립  주간   170   152  0.817  0.047  0.009  ...
# 3  강남구             개포중학교   3  공립  주간    83    72  0.755  0.097  0.013  ...
# 4  서초구             경원중학교   3  공립  주간   199   212  0.669  0.017  0.007  ...
#
#    마이스터고    자사고    자공고   기타진학  취업     미상         위도          경도  location  \
# 0  0.011  0.227  0.000  0.004   0  0.000  37.594942  127.038909        16
# 1  0.000  0.043  0.004  0.031   0  0.000  37.577473  127.003857        22
# 2  0.006  0.090  0.003  0.009   0  0.003  37.491637  127.071744         0
# 3  0.019  0.065  0.000  0.019   0  0.000  37.480439  127.062201         0
# 4  0.000  0.282  0.000  0.010   0  0.000  37.510750  127.008900        14
#
#    type
# 0     1
# 1     1
# 2     0
# 3     0
# 4     0
#
# [5 rows x 22 columns]

# %%
# 3) 클러스터팅에 필요한 속성만 선택 -> X에 담기
column_list = [9,10,11,13,20,21] # 과학고, 외고국제고, 체고, 자사고, 지역(라벨링), 유형(라벨링)
X = df.iloc[:, column_list] #iloc[rows_index, col_index]
X
# Out:
#        과학고  외고_국제고  예고_체고    자사고  location  type
# 0    0.018   0.007  0.000  0.227        16     1
# 1    0.000   0.035  0.008  0.043        22     1
# 2    0.009   0.012  0.003  0.090         0     0
# 3    0.013   0.013  0.019  0.065         0     0
# 4    0.007   0.010  0.005  0.282        14     0
# ..     ...     ...    ...    ...       ...   ...
# 410  0.000   0.000  0.940  0.000         0     1
# 411  0.000   0.000  0.875  0.000         7     1
# 412  0.000   0.000  0.861  0.000         5     2
# 413  0.000   0.000  0.751  0.000        23     2
# 414  0.000   0.024  0.000  0.010         8     2
#
# [415 rows x 6 columns]

# %%
# X 정규화
X = preprocessing.StandardScaler().fit(X).transform(X)
X
# Out:
# array([[ 2.02375287, -0.57972902, -0.18926749,  1.84751715,  0.68262763,
#          0.40358412],
#        [-0.65047921,  1.84782097, -0.10221179, -0.48039958,  1.51542665,
#          0.40358412],
#        [ 0.68663683, -0.14623795, -0.1566216 ,  0.11423133, -1.53816976,
#         -0.68399646],
#        ...,
#        [-0.65047921, -1.18661652,  9.1801025 , -1.0244236 , -0.84417057,
#          1.4911647 ],
#        [-0.65047921, -1.18661652,  7.98308659, -1.0244236 ,  1.65422649,
#          1.4911647 ],
#        [-0.65047921,  0.89414062, -0.18926749, -0.89790638, -0.42777106,
#          1.4911647 ]])

# %% [markdown]
# ## DBSCAN 군집 모델 설정

# %%
from sklearn import cluster

# 한 데이터 포인트에서 eps 거리 안에 데이터가 min_samples 개수만큼 포함되어 있으면 클러스터로 포함
# eps : 핵심 포인트를 중심으로 측정되는 유클리디언 거리값
# min_samples : 핵심 포인트를 중심점으로 간주하는 주변 지역의 표본 수
dbm = cluster.DBSCAN(eps=0.3, min_samples=5)

# %% [markdown]
# ## 모델 학습하기

# %%
dbm.fit(X)
# Out:
# DBSCAN(eps=0.3)

# %% [markdown]
# ## 모델 예측 ( 군집 ) 확인하기

# %%
np.unique(dbm.labels_)

df['Cluster'] = dbm.labels_
df['Cluster'].value_counts()
# Out:
# -1    391
#  2      8
#  0      6
#  1      5
#  3      5
# Name: Cluster, dtype: int64

# %%
df.head()
# Out:
#     지역               학교명  코드  유형  주야  남학생수  여학생수    일반고   특성화고    과학고  ...  \
# 0  성북구    서울대학교사범대학부설중학교   3  국립  주간   277     0  0.585  0.148  0.018  ...
# 1  종로구  서울대학교사범대학부설여자중학교   3  국립  주간     0   256  0.680  0.199  0.000  ...
# 2  강남구             개원중학교   3  공립  주간   170   152  0.817  0.047  0.009  ...
# 3  강남구             개포중학교   3  공립  주간    83    72  0.755  0.097  0.013  ...
# 4  서초구             경원중학교   3  공립  주간   199   212  0.669  0.017  0.007  ...
#
#      자사고    자공고   기타진학  취업     미상         위도          경도  location  type  \
# 0  0.227  0.000  0.004   0  0.000  37.594942  127.038909        16     1
# 1  0.043  0.004  0.031   0  0.000  37.577473  127.003857        22     1
# 2  0.090  0.003  0.009   0  0.003  37.491637  127.071744         0     0
# 3  0.065  0.000  0.019   0  0.000  37.480439  127.062201         0     0
# 4  0.282  0.000  0.010   0  0.000  37.510750  127.008900        14     0
#
#    Cluster
# 0       -1
# 1       -1
# 2       -1
# 3       -1
# 4       -1
#
# [5 rows x 23 columns]

# %%
# 클러스터 그룹별 내용 확인

group_cols = [0,1,3] + column_list

grouped = df.groupby('Cluster')

for index, group in grouped:
  print(' * Cluster: ',index)
  print(' * len :', len(group))
  print(group.iloc[:,group_cols])
  print('----------------------------------')
  print('\n')
# Out:
#  * Cluster:  -1
#  * len : 391
#       지역               학교명  유형    과학고  외고_국제고  예고_체고    자사고  location  type
# 0    성북구    서울대학교사범대학부설중학교  국립  0.018   0.007  0.000  0.227        16     1
# 1    종로구  서울대학교사범대학부설여자중학교  국립  0.000   0.035  0.008  0.043        22     1
# 2    강남구             개원중학교  공립  0.009   0.012  0.003  0.090         0     0
# 3    강남구             개포중학교  공립  0.013   0.013  0.019  0.065         0     0
# 4    서초구             경원중학교  공립  0.007   0.010  0.005  0.282        14     0
# ..   ...               ...  ..    ...     ...    ...    ...       ...   ...
# 410  강남구           국립국악중학교  국립  0.000   0.000  0.940  0.000         0     1
# 411  금천구         국립전통예술중학교  국립  0.000   0.000  0.875  0.000         7     1
# 412  광진구            선화예술학교  사립  0.000   0.000  0.861  0.000         5     2
# 413   중구              예원학교  사립  0.000   0.000  0.751  0.000        23     2
# 414  노원구           한국삼육중학교  사립  0.000   0.024  0.000  0.010         8     2
#
# [391 rows x 9 columns]
# ----------------------------------
#
#
#  * Cluster:  0
#  * len : 6
#       지역    학교명  유형  과학고  외고_국제고  예고_체고    자사고  location  type
# 81   강서구  경서중학교  공립  0.0   0.007  0.000  0.036         3     0
# 97   강서구  삼정중학교  공립  0.0   0.007  0.000  0.027         3     0
# 187  관악구  당곡중학교  공립  0.0   0.004  0.007  0.025         4     0
# 192  관악구  미성중학교  공립  0.0   0.005  0.014  0.023         4     0
# 193  관악구  봉림중학교  공립  0.0   0.006  0.006  0.044         4     0
# 201  관악구  신관중학교  공립  0.0   0.007  0.007  0.007         4     0
# ----------------------------------
#
#
#  * Cluster:  1
#  * len : 5
#       지역    학교명  유형  과학고  외고_국제고  예고_체고    자사고  location  type
# 117  금천구  가산중학교  공립  0.0   0.009  0.014  0.014         7     0
# 132  금천구  세일중학교  공립  0.0   0.006  0.012  0.024         7     0
# 135  금천구  안천중학교  공립  0.0   0.005  0.000  0.033         7     0
# 145  구로구  오류중학교  공립  0.0   0.004  0.021  0.026         6     0
# 377  구로구  천왕중학교  공립  0.0   0.004  0.028  0.032         6     0
# ----------------------------------
#
#
#  * Cluster:  2
#  * len : 8
#       지역     학교명  유형  과학고  외고_국제고  예고_체고  자사고  location  type
# 387  강서구    교남학교  사립  0.0     0.0    0.0  0.0         3     2
# 389  강남구    밀알학교  사립  0.0     0.0    0.0  0.0         0     2
# 390  관악구    새롬학교  사립  0.0     0.0    0.0  0.0         4     2
# 394  강북구  서울애화학교  사립  0.0     0.0    0.0  0.0         2     2
# 400  구로구  성베드로학교  사립  0.0     0.0    0.0  0.0         6     2
# 403  강동구    주몽학교  사립  0.0     0.0    0.0  0.0         1     2
# 404  강동구  한국구화학교  사립  0.0     0.0    0.0  0.0         1     2
# 406  강북구   한빛맹학교  사립  0.0     0.0    0.0  0.0         2     2
# ----------------------------------
#
#
#  * Cluster:  3
#  * len : 5
#       지역     학교명  유형  과학고  외고_국제고  예고_체고    자사고  location  type
# 118  구로구   개봉중학교  공립  0.0     0.0  0.004  0.012         6     0
# 391  광진구  서울광진학교  공립  0.0     0.0  0.000  0.000         5     0
# 396  관악구  서울정문학교  공립  0.0     0.0  0.000  0.000         4     0
# 397  노원구  서울정민학교  공립  0.0     0.0  0.000  0.000         8     0
# 399  구로구  서울정진학교  공립  0.0     0.0  0.000  0.000         6     0
# ----------------------------------

# %% [markdown]
# ## 클러스터링 결과 지도 시각화

# %%
mschool_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', zoom_start=12)

colors = {-1: 'gray', 0:'coral', 1:'blue', 2:'green', 3:'red', 4:'purple', 5:'orange'}

# 중학교의 위치정보를 CircleMarker로 표시 -> popup 학교명 출력
for name, lat, lng, clus in zip(df.학교명, df.위도, df.경도, df.Cluster):
  folium.CircleMarker([lat,lng], #위도, 경도
                      radius=5, # 반지름
                      color=colors[clus], #둘레 색상
                      fill=True,
                      fill_color=colors[clus], #원안에 색상
                      fill_opacity=0.7, #투명도
                      popup='<pre>'+name+'</pre>').add_to(mschool_map)

mschool_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_219a2852abeed2c476396c4cd004d01b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_219a2852abeed2c476396c4cd004d01b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_219a2852abeed2c476396c4cd004d01b = L.map(
#                 &quot;map_219a2852abeed2c476396c4cd004d01b&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c11a960a50d8c60545758f3cc8339cf9 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_219a2852abeed2c476396c4cd004d01b);
#
#
#             var circle_marker_f0e3fb7d11e418b94c217bd238f94063 = L.circleMarker(
#                 [37.5949423, 127.0389086],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_219a2852abeed2c476396c4cd004d01b);
#
#
#         var popup_8f110d7e605abcee016b40898a8aeb7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c3aebc089e55e68888f2849c0d1498a = $(`&lt;div id=&quot;html_3c3aebc089e55e68888f2849c0d1498a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;서울대학교사범대학부설중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_8f110d7e605abcee016b40898a8aeb7a.setContent(html_3c3aebc089e55e68888f2849c0d1498a);
#
#
#
#         circle_marker_f0e3fb7d11e418b94c217bd238f94063.bindPopup(popup_8f110d7e605abcee016b40898a8aeb7a)
#         ;
#
#
#
#
#             var circle_marker_790595438cab58a9b9642dbd41b62886 = L.circleMarker(
#                 [37.5774729, 127.0038567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_219a2852abeed2c476396c4cd004d01b);
#
#
#         var popup_edbf324a6c8a549acc8d4285d0475975 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c55727097eb241698b6f604b31f68bd = $(`&lt;div id=&quot;html_5c55727097eb241698b6f604b31f68bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;서울대학교사범대학부설여자중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_edbf324a6c8a549acc8d4285d0475975.setContent(html_5c55727097eb241698b6f604b31f68bd);
#
#
#
#         circle_marker_790595438cab58a9b9642dbd41b62886.bindPopup(popup_edbf324a6c8a549acc8d4285d0475975)
#         ;
#
#
#
#
#             var circle_marker_39c1e2f4bbba697faa759c4bab9c3011 = L.circleMarker(
#                 [37.4916369, 127.0717443],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_219a2852abeed2c476396c4cd004d01b);
#
#
#         var popup_bea136b0c212c9d1eea1bac0fbd7ccca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_008b5c118add70909095b17467130234 = $(`&lt;div id=&quot;html_008b5c118add70909095b17467130234&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;개원중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_bea136b0c212c9d1eea1bac0fbd7ccca.setContent(html_008b5c118add70909095b17467130234);
#
#
#
#         circle_marker_39c1e2f4bbba697faa759c4bab9c3011.bindPopup(popup_bea136b0c212c9d

# %%
# 3) 클러스터팅에 필요한 속성만 선택 -> X에 담기
column_list = [9,10,11,13] #  과학고, 외고국제고, 체고,  자사고
X = df.iloc[:, column_list] #iloc[rows_index, col_index]
X
# Out:
#        과학고  외고_국제고  예고_체고    자사고
# 0    0.018   0.007  0.000  0.227
# 1    0.000   0.035  0.008  0.043
# 2    0.009   0.012  0.003  0.090
# 3    0.013   0.013  0.019  0.065
# 4    0.007   0.010  0.005  0.282
# ..     ...     ...    ...    ...
# 410  0.000   0.000  0.940  0.000
# 411  0.000   0.000  0.875  0.000
# 412  0.000   0.000  0.861  0.000
# 413  0.000   0.000  0.751  0.000
# 414  0.000   0.024  0.000  0.010
#
# [415 rows x 4 columns]

# %%
# X 정규화
X = preprocessing.StandardScaler().fit(X).transform(X)
X
# Out:
# array([[ 2.02375287, -0.57972902, -0.18926749,  1.84751715],
#        [-0.65047921,  1.84782097, -0.10221179, -0.48039958],
#        [ 0.68663683, -0.14623795, -0.1566216 ,  0.11423133],
#        ...,
#        [-0.65047921, -1.18661652,  9.1801025 , -1.0244236 ],
#        [-0.65047921, -1.18661652,  7.98308659, -1.0244236 ],
#        [-0.65047921,  0.89414062, -0.18926749, -0.89790638]])

# %%
from sklearn import cluster

# 한 데이터 포인트에서 eps 거리 안에 데이터가 min_samples 개수만큼 포함되어 있으면 클러스터로 포함
# eps : 핵심 포인트를 중심으로 측정되는 유클리디언 거리값
# min_samples : 핵심 포인트를 중심점으로 간주하는 주변 지역의 표본 수
dbm = cluster.DBSCAN(eps=0.3, min_samples=5)

# %%
dbm.fit(X)
# Out:
# DBSCAN(eps=0.3)

# %%
np.unique(dbm.labels_)

df['Cluster'] = dbm.labels_
df['Cluster'].value_counts()
# Out:
# -1    218
#  0    159
#  1     12
#  3     11
#  2     10
#  4      5
# Name: Cluster, dtype: int64

# %%
# 클러스터 그룹별 내용 확인

group_cols = [0,1,3] + column_list

grouped = df.groupby('Cluster')

for index, group in grouped:
  print(' * Cluster: ',index)
  print(' * len :', len(group))
  print(group.iloc[:,group_cols])
  print('----------------------------------')
  print('\n')
# Out:
#  * Cluster:  -1
#  * len : 218
#       지역               학교명  유형    과학고  외고_국제고  예고_체고    자사고
# 0    성북구    서울대학교사범대학부설중학교  국립  0.018   0.007  0.000  0.227
# 1    종로구  서울대학교사범대학부설여자중학교  국립  0.000   0.035  0.008  0.043
# 2    강남구             개원중학교  공립  0.009   0.012  0.003  0.090
# 3    강남구             개포중학교  공립  0.013   0.013  0.019  0.065
# 4    서초구             경원중학교  공립  0.007   0.010  0.005  0.282
# ..   ...               ...  ..    ...     ...    ...    ...
# 386  종로구             서울맹학교  국립  0.000   0.000  0.077  0.000
# 410  강남구           국립국악중학교  국립  0.000   0.000  0.940  0.000
# 411  금천구         국립전통예술중학교  국립  0.000   0.000  0.875  0.000
# 412  광진구            선화예술학교  사립  0.000   0.000  0.861  0.000
# 413   중구              예원학교  사립  0.000   0.000  0.751  0.000
#
# [218 rows x 7 columns]
# ----------------------------------
#
#
#  * Cluster:  0
#  * len : 159
#       지역      학교명  유형  과학고  외고_국제고  예고_체고    자사고
# 13   서초구  동덕여자중학교  사립  0.0   0.022  0.000  0.038
# 22   강남구    수서중학교  공립  0.0   0.019  0.000  0.044
# 28   서초구    언남중학교  공립  0.0   0.015  0.035  0.050
# 29   강남구    언북중학교  공립  0.0   0.007  0.007  0.087
# 34   강남구    은성중학교  사립  0.0   0.016  0.011  0.065
# ..   ...      ...  ..  ...     ...    ...    ...
# 406  강북구    한빛맹학교  사립  0.0   0.000  0.000  0.000
# 407  은평구   은평대영학교  사립  0.0   0.000  0.000  0.000
# 408  종로구   서울경운학교  공립  0.0   0.000  0.000  0.000
# 409  성북구   서울다원학교  공립  0.0   0.000  0.000  0.000
# 414  노원구  한국삼육중학교  사립  0.0   0.024  0.000  0.010
#
# [159 rows x 7 columns]
# ----------------------------------
#
#
#  * Cluster:  1
#  * len : 12
#        지역    학교명  유형    과학고  외고_국제고  예고_체고    자사고
# 20    서초구  서초중학교  공립  0.003   0.013  0.003  0.085
# 60    송파구  세륜중학교  공립  0.004   0.017  0.004  0.052
# 75    강동구  천호중학교  공립  0.003   0.015  0.006  0.054
# 76    송파구  풍납중학교  공립  0.005   0.016  0.005  0.069
# 79    강동구  한영중학교  사립  0.004   0.011  0.000  0.077
# 122   구로구  구일중학교  공립  0.004   0.012  0.008  0.079
# 188   동작구  대방중학교  공립  0.003   0.015  0.021  0.076
# 214   도봉구  도봉중학교  공립  0.004   0.011  0.000  0.072
# 252  서대문구  명지중학교  사립  0.006   0.018  0.000  0.061
# 261   마포구  성서중학교  공립  0.004   0.016  0.004  0.067
# 288   광진구  광양중학교  공립  0.004   0.012  0.015  0.077
# 310   강북구  번동중학교  공립  0.004   0.014  0.000  0.072
# ----------------------------------
#
#
#  * Cluster:  2
#  * len : 10
#       지역    학교명  유형    과학고  외고_국제고  예고_체고    자사고
# 94   강서구  방화중학교  공립  0.005   0.010  0.015  0.021
# 116  강서구  화원중학교  공립  0.003   0.010  0.000  0.003
# 119  구로구  개웅중학교  공립  0.003   0.009  0.003  0.016
# 184  관악구  남강중학교  사립  0.006   0.011  0.000  0.045
# 219  노원구  상경중학교  공립  0.003   0.009  0.003  0.021
# 229  노원구  신창중학교  공립  0.005   0.010  0.010  0.044
# 268  은평구  연서중학교  공립  0.004   0.008  0.000  0.027
# 289  광진구  광장중학교  공립  0.003   0.010  0.010  0.047
# 345  용산구  오산중학교  사립  0.005   0.009  0.000  0.046
# 367  강서구  수명중학교  공립  0.004   0.008  0.004  0.032
# ----------------------------------
#
#
#  * Cluster:  3
#  * len : 11
#        지역             학교명  유형    과학고  외고_국제고  예고_체고    자사고
# 143   구로구           오남중학교  공립  0.004   0.004  0.027  0.035
# 152  동대문구  동국대학교사범대학부속중학교  사립  0.004   0.004  0.000  0.067
# 163   중랑구           용마중학교  공립  0.003   0.003  0.000  0.030
# 166  동대문구           장평중학교  공립  0.003   0.003  0.016  0.060
# 211   노원구           노원중학교  공립  0.004   0.004  0.008  0.047
# 247   은평구           구산중학교  공립  0.003   0.003  0.000  0.055
# 269   은평구           연신중학교  공립  0.004   0.004  0.000  0.065
# 274   은평구           은평중학교  공립  0.003   0.003  0.007  0.079
# 280   은평구           증산중학교  공립  0.005   0.005  0.010  0.045
# 308   성북구          남대문중학교  사립  0.004   0.007  0.000  0.078
# 337   용산구           배문중학교  사립  0.005   0.005  0.005  0.038
# ----------------------------------
#
#
#  * Cluster:  4
#  * len : 5
#        지역             학교명  유형    과학고  외고_국제고  예고_체고    자사고
# 50    송파구           방산중학교  공립  0.007   0.021  0.007  0.109
# 147  영등포구           윤중중학교  공립  0.007   0.018  0.011  0.113
# 207   동작구  중앙대학교사범대학부속중학교  사립  0.006   0.019  0.015  0.108
# 294   성동구           동마중학교  공립  0.005   0.020  0.005  0.114
# 376   마포구           창천중학교  공립  0.007   0.020  0.034  0.101
# ----------------------------------

# %%
mschool_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', zoom_start=12)

colors = {-1: 'gray', 0:'coral', 1:'blue', 2:'green', 3:'red', 4:'purple', 5:'orange'}

# 중학교의 위치정보를 CircleMarker로 표시 -> popup 학교명 출력
for name, lat, lng, clus in zip(df.학교명, df.위도, df.경도, df.Cluster):
  folium.CircleMarker([lat,lng], #위도, 경도
                      radius=5, # 반지름
                      color=colors[clus], #둘레 색상
                      fill=True,
                      fill_color=colors[clus], #원안에 색상
                      fill_opacity=0.7, #투명도
                      popup='<pre>'+name+'</pre>').add_to(mschool_map)

mschool_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0902a929d63134e02130c418e01cde99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0902a929d63134e02130c418e01cde99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0902a929d63134e02130c418e01cde99 = L.map(
#                 &quot;map_0902a929d63134e02130c418e01cde99&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ffd1429733973a39cd8fbcbcc644f30 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0902a929d63134e02130c418e01cde99);
#
#
#             var circle_marker_286102d6a965304afef6eb4abcb8bda9 = L.circleMarker(
#                 [37.5949423, 127.0389086],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0902a929d63134e02130c418e01cde99);
#
#
#         var popup_8e295a2d0d968862193ac6f45c9cefbc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d36ac82a3a513282dd4a4709b5297bea = $(`&lt;div id=&quot;html_d36ac82a3a513282dd4a4709b5297bea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;서울대학교사범대학부설중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_8e295a2d0d968862193ac6f45c9cefbc.setContent(html_d36ac82a3a513282dd4a4709b5297bea);
#
#
#
#         circle_marker_286102d6a965304afef6eb4abcb8bda9.bindPopup(popup_8e295a2d0d968862193ac6f45c9cefbc)
#         ;
#
#
#
#
#             var circle_marker_a76eab4d07af6d42781ebe0b0ff5a5c8 = L.circleMarker(
#                 [37.5774729, 127.0038567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0902a929d63134e02130c418e01cde99);
#
#
#         var popup_2258c07e48bef591ab910805ab3a987b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4686468bfd23282c30b1abbe8323628 = $(`&lt;div id=&quot;html_e4686468bfd23282c30b1abbe8323628&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;서울대학교사범대학부설여자중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_2258c07e48bef591ab910805ab3a987b.setContent(html_e4686468bfd23282c30b1abbe8323628);
#
#
#
#         circle_marker_a76eab4d07af6d42781ebe0b0ff5a5c8.bindPopup(popup_2258c07e48bef591ab910805ab3a987b)
#         ;
#
#
#
#
#             var circle_marker_e86c27f2367853af9f44688913a06c31 = L.circleMarker(
#                 [37.4916369, 127.0717443],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0902a929d63134e02130c418e01cde99);
#
#
#         var popup_0221c486ba68551ee34ed190482cced8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0fc9a226147dc926b4a6507ec7eddb20 = $(`&lt;div id=&quot;html_0fc9a226147dc926b4a6507ec7eddb20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;개원중학교&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_0221c486ba68551ee34ed190482cced8.setContent(html_0fc9a226147dc926b4a6507ec7eddb20);
#
#
#
#         circle_marker_e86c27f2367853af9f44688913a06c31.bindPopup(popup_0221c486ba68551
